# %% [markdown]
# <a href="https://colab.research.google.com/github/rpfilomeno/JupiterNotebooks/blob/main/Ace_music_1_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.9.29 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !git clone --depth 1 https://github.com/ace-step/ACE-Step-1.5.git
# Out:
# Cloning into 'ACE-Step-1.5'...
# remote: Enumerating objects: 538, done.
# remote: Counting objects: 100% (538/538), done.
# remote: Compressing objects: 100% (528/528), done.
# remote: Total 538 (delta 5), reused 313 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (538/538), 5.82 MiB | 13.96 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd ACE-Step-1.5
# Out:
# /content/ACE-Step-1.5

# %%
# !uv sync
# Out:
# Using CPython 3.11.14
# Creating virtual environment at: .venv
# Resolved 127 packages in 12.89s
# Prepared 115 packages in 1m 46s
# Installed 116 packages in 829ms
#  + accelerate==1.12.0
#  + ace-step==1.5.0 (from file:///content/ACE-Step-1.5)
#  + aiofiles==24.1.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + brotli==1.2.0
#  + certifi==2026.1.4
#  + cffi==2.0.0
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + contourpy==1.3.3
#  + cuda-bindings==12.9.4
#  + cuda-pathfinder==1.3.3
#  + cycler==0.12.1
#  + diffusers==0.36.0
#  + diskcache==5.6.3
#  + einops==0.8.2
#  + einx==0.3.0
#  + fastapi==0.128.0
#  + ffmpy==1.0.0
#  + filelock==3.20.3
#  + flash-attn==2.8.3+cu128torch2.10 (from https://github.com/mjun0812/flash-attention-prebuild-wheels/releases/download/v0.7.12/flash_attn-2.8.3+cu128torch2.10-cp311-cp311-linux_x86_64.whl)
#  + fonttools==4.61.1
#  + frozendict==2.4.7
#  + fsspec==2026.1.0
#  + gradio==6.5.1
#  + gradio-client==2.0.3
# ...

# %%
# !uv run acestep --share
# Out:
# Loaded configuration from /content/ACE-Step-1.5/.env.example (fallback)
# Skipping import of cpp extensions due to incompatible torch version 2.10.0+cu128 for torchao version 0.15.0             Please see https://github.com/pytorch/ao/issues/2919 for more info
# 2026-02-04 04:42:52.386 | WARNING  | acestep.training.lora_utils:<module>:26 - PEFT library not installed. LoRA training will not be available.
# 2026-02-04 04:42:52.387 | WARNING  | acestep.training.data_module:<module>:23 - Lightning not installed. Training module will not be available.
# 2026-02-04 04:42:52.388 | WARNING  | acestep.training.trainer:<module>:25 - Lightning Fabric not installed. Training will use basic training loop.
#
# ...
# GPU Configuration Detected:
# ...
#   GPU Memory: 14.74 GB
#   Configuration Tier: tier5
#   Max Duration (with LM): 240s (4 min)
#   Max Duration (without LM): 360s (6 min)
#   Max Batch Size (with LM): 2
#   Max Batch Size (without LM): 4
#   Default LM Init: True
# ...
